# %% [markdown]
# <a id="top"></a>
# <span><h1 style="font-family:verdana;"><center><img src="https://seaborn.pydata.org/_static/logo-wide-lightbg.svg" alt="Seaborn" width=200></center></h1></span>
# <p><center style="color:#159364; font-family:cursive;">Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.</center></p>
#
# ***

# %% [markdown]
# <h2><center>Installation of seaborn</center></h2>

# %% [markdown]
# <h3>Requirements:</h3>
# <p>1. You need to install Python and Pip in your system <code>python -m pip install -U pip</code></p>
# <p>2. Open your cmd and run <code>pip install seaborn --user</code></p>

# %% [markdown]
# <h2><center>Distplots</center></h2>

# %% [markdown]
# <p>Distplot stands for distribution plot, it takes as input an array and plots a curve corresponding to the distribution of points in the array.</p>

# %% [markdown]
# <p>If you want to ignore unnecessary warnings run following commands<br><code>import warnings
# warnings.filterwarnings('ignore')</code></p>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([0, 1, 2, 3, 4, 5])

plt.show()

# %% [markdown]
# <h5>Drawing Displot without Histogram</h5>

# %%
sns.distplot([10, 15, 21, 34, 49, 60], hist=False)

plt.show()

# %% [markdown]
# <h5>Scatterplot with Regression Line</h5>
# <p>A scatter plot with a regression line can be used to visualize the relationship between two variables.</p>

# %%
import pandas as pd

df = pd.read_csv('data.csv')

# df.head() if a built in function in Python, which will by default show the first 5 Rows
df.head()
# Out:
#    matches  h_runs  l_runs  strike_rate
# 0       60     110     130          214
# 1       60     117     145          100
# 2       60     103     135          232
# 3       45     109     175          127
# 4       45     117     148          131

# %%
# Plot between Duration and Pulse

# create a scatterplot with regression line
sns.lmplot(x="matches", y="strike_rate", data=df)

# show the plot
plt.show()

# %%
# Plot between Maxpulse and Pulse

# create a scatterplot with regression line
sns.lmplot(x="matches", y="h_runs", data=df)

# show the plot
plt.show()

# %%
#Box-Plot  b/w MaxPulse and Pulse

sns.boxplot(x="matches", y="l_runs", data=df)

# show the plot
plt.show()

# %%
#Box-Plot  b/w Duration and Pulse

sns.boxplot(x="matches", y="strike_rate", data=df)

# show the plot
plt.show()

# %%
# create a violinplot
sns.violinplot(x="h_runs", y="l_runs", data=df)

# show the plot
plt.show()

# %%
# create a violinplot
sns.violinplot(x="l_runs", y="strike_rate", data=df)

# show the plot
plt.show()
